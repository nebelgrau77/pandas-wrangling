# %%
# Sales of Hybrid Electric Vehicles in Europe in 2017 (Q1 – Q4)

# from: https://www.best-selling-cars.com/europe/2017-full-year-europe-electric-hybrid-vehicle-sales-per-eu-efta-country/

# %%
import re

# %%
# whole table HTML copypasted

table = '''<table dir="ltr" cellspacing="0" cellpadding="0"><tbody><tr><td> </td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Q4/2017&quot;}">Q4/2017</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Q4/2016&quot;}">Q4/2016</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change&quot;}" data-sheets-numberformat="[null,2,&quot;\\+0.0;\\-0.0&quot;,1]">% Change</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2017}">2017</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2016}">2016</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change&quot;}" data-sheets-numberformat="[null,2,&quot;\\+0.0;\\-0.0&quot;,1]">% Change</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;AUSTRIA&quot;}">AUSTRIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1673}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,673</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1062}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,062</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:57.53295668549906}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">57.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6572}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6,572</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3474}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,474</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:89.17674150834772}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">89.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;BELGIUM&quot;}">BELGIUM</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2462}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,462</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2348}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,348</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4.855195911413969}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">4.9</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:12571}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">12,571</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9501}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">9,501</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:32.31238816966635}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">32.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;BULGARIA&quot;}">BULGARIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:412}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">412</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:258}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">258</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:59.68992248062015}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">59.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1195}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,195</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:580}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">580</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:106.03448275862068}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">106.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;CZECH REPUBLIC&quot;}">CZECH REPUBLIC</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:787}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">787</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:461}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">461</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:70.71583514099783}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">70.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2826}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,826</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1541}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,541</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:83.38741077222582}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">83.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;DENMARK&quot;}">DENMARK</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1513}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,513</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1377}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,377</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9.876543209876543}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">9.9</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7101}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,101</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6781}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6,781</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4.7190679840731455}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">4.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ESTONIA&quot;}">ESTONIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:238}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">238</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:194}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">194</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:22.68041237113402}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">22.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1188}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,188</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:765}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">765</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:55.294117647058826}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">55.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;FINLAND&quot;}">FINLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1703}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,703</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1117}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,117</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:52.46195165622203}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">52.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:8514}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">8,514</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4678}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,678</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:82.00085506626763}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">82.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;FRANCE&quot;}">FRANCE</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:20098}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">20,098</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15445}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">15,445</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:30.126254451278733}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">30.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:69680}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">69,680</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:50956}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">50,956</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:36.74542742758458}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">36.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;GERMANY&quot;}">GERMANY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15150}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">15,150</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:10543}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">10,543</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:43.69723987479844}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">43.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:55236}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">55,236</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:34245}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">34,245</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:61.296539640823475}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">61.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;GREECE&quot;}">GREECE</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:737}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">737</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:394}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">394</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:87.05583756345177}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">87.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2348}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,348</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1545}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,545</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51.97411003236246}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">52.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;HUNGARY&quot;}">HUNGARY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:994}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">994</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:530}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">530</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:87.54716981132076}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">87.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3539}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,539</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1674}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,674</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:111.40979689366786}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">111.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;IRELAND&quot;}">IRELAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:91}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">91</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">13</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:600}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">600.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4435}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,435</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2570}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,570</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:72.568093385214}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">72.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ITALY&quot;}">ITALY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:17415}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">17,415</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:10171}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">10,171</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:71.22210205486186}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">71.2</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:63398}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">63,398</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:37240}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">37,240</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:70.24167561761546}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">70.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LATVIA&quot;}">LATVIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:124}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">124</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:115}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">115</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7.82608695652174}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">7.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:344}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">344</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:286}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">286</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:20.27972027972028}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">20.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LITHUANIA&quot;}">LITHUANIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:214}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">214</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:107}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">107</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:100}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">100.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:715}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">715</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:401}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">401</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:78.30423940149626}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">78.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;NETHERLANDS&quot;}">NETHERLANDS</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4254}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,254</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4187}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,187</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1.60019106759016}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">1.6</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:17667}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">17,667</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:10972}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">10,972</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:61.01895734597157}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">61.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;POLAND&quot;}">POLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4852}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,852</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2909}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,909</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:66.7927122722585}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">66.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:16896}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">16,896</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:10050}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">10,050</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:68.11940298507463}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">68.1</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;PORTUGAL &quot;}">PORTUGAL</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1376}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,376</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:981}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">981</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:40.26503567787971}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">40.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4692}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,692</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3204}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,204</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:46.441947565543074}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">46.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ROMANIA&quot;}">ROMANIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:570}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">570</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:405}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">405</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:40.74074074074074}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">40.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2039}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,039</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1089}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,089</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:87.23599632690542}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">87.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SLOVAKIA&quot;}">SLOVAKIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:558}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">558</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:149}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">149</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:274.496644295302}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">274.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1936}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,936</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:363}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">363</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:433.3333333333333}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">433.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SLOVENIA&quot;}">SLOVENIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:286}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">286</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:87}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">87</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:228.73563218390808}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">228.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1005}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,005</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:369}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">369</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:172.3577235772358}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">172.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SPAIN&quot;}">SPAIN</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15002}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">15,002</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9073}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">9,073</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:65.34773503802491}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">65.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:55522}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">55,522</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:30897}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">30,897</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:79.70029452697673}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">79.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SWEDEN&quot;}">SWEDEN</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:5600}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">5,600</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3690}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,690</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51.76151761517615}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">51.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:19562}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">19,562</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13759}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">13,759</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:42.17603023475544}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">42.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;UNITED KINGDOM&quot;}">UNITED KINGDOM</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13833}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">13,833</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11113}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">11,113</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:24.47583910735175}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">24.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:72523}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">72,523</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51789}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">51,789</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:40.035528780242906}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">40.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EUROPEAN UNION&quot;}">EUROPEAN UNION</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:109942}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">109,942</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:76729}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">76,729</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:43.28611085769396}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">43.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:431504}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">431,504</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:278729}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">278,729</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:54.811304170000255}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">54.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU15&quot;}">EU15</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:100907}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">100,907</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:71514}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">71,514</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:41.10104315238974}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">41.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:399821}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">399,821</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:261611}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">261,611</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:52.830347347779714}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">52.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU (New Members)&quot;}">EU (New Members)</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9035}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">9,035</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:5215}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">5,215</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:73.25023969319271}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">73.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:31683}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">31,683</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:17118}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">17,118</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:85.08587451805117}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">85.1</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;NORWAY&quot;}">NORWAY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4798}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,798</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4216}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,216</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13.804554079696393}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">13.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:20500}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">20,500</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:17259}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">17,259</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:18.778608262355874}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">18.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SWITZERLAND&quot;}">SWITZERLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2213}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,213</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2099}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,099</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:5.431157694140067}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">5.4</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:8414}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">8,414</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7673}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,673</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9.657239671575654}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">9.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EFTA&quot;}">EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7011}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,011</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6315}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6,315</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11.021377672209026}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">11.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:28914}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">28,914</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:24932}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">24,932</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15.971442323118884}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">16.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU + EFTA&quot;}">EU + EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:116953}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">116,953</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:83044}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">83,044</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:40.832570685419775}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">40.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:460418}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">460,418</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:303661}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">303,661</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51.622368364722504}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">51.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU15 + EFTA&quot;}">EU15 + EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:107918}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">107,918</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:77829}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">77,829</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:38.66039651029822}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">38.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:428735}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">428,735</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:286543}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">286,543</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:49.623267712001336}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">49.6</td>
</tr>
<tr>
<td> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
</tr>
</tbody>
</table>'''

# %%
# remove new line tags otherwise it won't work well

table = table.replace('\n','')

# %%
rows = re.split('</tr>', table)

# %%
# finding alphanumeric (\w), whitespace (\s), commas, plus signs, %, /, decimal points and brackets
data_rows = []

for row in rows:
    extracted = re.findall('>([\w\s%/,+\.\(\)]*?)</td', row)
    print(extracted)
    data_rows.append(extracted)
# Out:
# [' ', 'Q4/2017', 'Q4/2016', '% Change', '2017', '2016', '% Change']
# ['AUSTRIA', '1,673', '1,062', '57.5', '6,572', '3,474', '89.2']
# ['BELGIUM', '2,462', '2,348', '4.9', '12,571', '9,501', '32.3']
# ['BULGARIA', '412', '258', '59.7', '1,195', '580', '106.0']
# ['CZECH REPUBLIC', '787', '461', '70.7', '2,826', '1,541', '83.4']
# ['DENMARK', '1,513', '1,377', '9.9', '7,101', '6,781', '4.7']
# ['ESTONIA', '238', '194', '22.7', '1,188', '765', '55.3']
# ['FINLAND', '1,703', '1,117', '52.5', '8,514', '4,678', '82.0']
# ['FRANCE', '20,098', '15,445', '30.1', '69,680', '50,956', '36.7']
# ['GERMANY', '15,150', '10,543', '43.7', '55,236', '34,245', '61.3']
# ['GREECE', '737', '394', '87.1', '2,348', '1,545', '52.0']
# ['HUNGARY', '994', '530', '87.5', '3,539', '1,674', '111.4']
# ['IRELAND', '91', '13', '600.0', '4,435', '2,570', '72.6']
# ['ITALY', '17,415', '10,171', '71.2', '63,398', '37,240', '70.2']
# ['LATVIA', '124', '115', '7.8', '344', '286', '20.3']
# ...

# %%
import pandas as pd

# %%
['Country'] + data_rows[0][1:]
# Out:
# ['Country', 'Q4/2017', 'Q4/2016', '% Change', '2017', '2016', '% Change']

# %%
# create a dataframe with a correct header

data = pd.DataFrame(columns = ['Country'] + data_rows[0][1:])

# %%
data
# Out:
# Empty DataFrame
# Columns: [Country, Q4/2017, Q4/2016, % Change, 2017, 2016, % Change]
# Index: []

# %%
for number, row in enumerate(data_rows[1:-2]): # for each row (skip the first and the last two)
    for n, col in enumerate(data.columns): # and for each column of the dataframe
        data.loc[number,col] = row[n] # put the values into the correct rows and columns

# %%
data.head()
# Out:
#           Country Q4/2017 Q4/2016 % Change    2017   2016 % Change
# 0         AUSTRIA   1,673   1,062     89.2   6,572  3,474     89.2
# 1         BELGIUM   2,462   2,348     32.3  12,571  9,501     32.3
# 2        BULGARIA     412     258    106.0   1,195    580    106.0
# 3  CZECH REPUBLIC     787     461     83.4   2,826  1,541     83.4
# 4         DENMARK   1,513   1,377      4.7   7,101  6,781      4.7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 7 columns):
# Country     32 non-null object
# Q4/2017     32 non-null object
# Q4/2016     32 non-null object
# % Change    32 non-null object
# 2017        32 non-null object
# 2016        32 non-null object
# % Change    32 non-null object
# dtypes: object(7)
# memory usage: 3.2+ KB

# %%
# remove commas

data = data.applymap(lambda x: x.replace(',',''))

# %%
# convert sales volumes to integers

for col in ['Q4/2017', 'Q4/2016','2017','2016']:
    data[col] = data[col].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 7 columns):
# Country     32 non-null object
# Q4/2017     32 non-null int32
# Q4/2016     32 non-null int32
# % Change    32 non-null object
# 2017        32 non-null int32
# 2016        32 non-null int32
# % Change    32 non-null object
# dtypes: int32(4), object(3)
# memory usage: 2.8+ KB

# %%
# the % Change columns are not necessary as it can be calculated directly in pandas

data = data.drop('% Change', axis = 1)

# %%
# recalculate the % changes

data['% delta Q4 to Q4'] = (data['Q4/2017'] - data['Q4/2016'])/data['Q4/2016']*100

# %%
data['% delta 2017/2016'] = (data['2017'] - data['2016'])/data['2016']*100

# %%
data.head()
# Out:
#           Country  Q4/2017  Q4/2016   2017  2016  % delta Q4 to Q4  \
# 0         AUSTRIA     1673     1062   6572  3474         57.532957
# 1         BELGIUM     2462     2348  12571  9501          4.855196
# 2        BULGARIA      412      258   1195   580         59.689922
# 3  CZECH REPUBLIC      787      461   2826  1541         70.715835
# 4         DENMARK     1513     1377   7101  6781          9.876543
#
#    % delta 2017/2016
# 0          89.176742
# 1          32.312388
# 2         106.034483
# 3          83.387411
# 4           4.719068

# %%
# round the last two columns to two decimal points

data[data.columns[-2:]] = data[data.columns[-2:]].round(2)

# %%
data.head()
# Out:
#           Country  Q4/2017  Q4/2016   2017  2016  % delta Q4 to Q4  \
# 0         AUSTRIA     1673     1062   6572  3474             57.53
# 1         BELGIUM     2462     2348  12571  9501              4.86
# 2        BULGARIA      412      258   1195   580             59.69
# 3  CZECH REPUBLIC      787      461   2826  1541             70.72
# 4         DENMARK     1513     1377   7101  6781              9.88
#
#    % delta 2017/2016
# 0              89.18
# 1              32.31
# 2             106.03
# 3              83.39
# 4               4.72

# %%
all_electric = '''<h2>The European Electric Car Market in 2017 (Full Year)</h2>
<p>New electrically chargeable vehicle (ECV) registrations in the European Union (EU) and EFTA countries increased by 38.7% to 287,270 cars. During the fourth quarter 2017, the increase was slightly weaker at 37% to just over 86,000 electric cars.</p>
<p>Despite the strong growth in electric car sales in Europe in 2017, electrically chargeable vehicles still have a market share of only 1.4%, which is around one in 60 new cars.</p>
<ul>
<li><strong>Note:</strong> Terminology used in these <a href="http://www.acea.be">ACEA</a> statistics: Electrically chargeable vehicle (ECV) = battery electric vehicles (BEV) + extended-range electric vehicles (EREV) + fuel cell electric vehicles (FCEV) + plug-in hybrid electric vehicles (PHEV).</li>
</ul>
<h2>Electric Car Sales Per European Union and EFTA Country in 2017 (Q1-Q4)</h2>
<p>Registrations of electrically chargeable vehicles (ECV) in European Union and EFTA member countries during Q4 (October to December) and full year 2017 were as follows according to <a href="http://www.acea.be">ACEA</a> statistics:</p>
<table dir="ltr" cellspacing="0" cellpadding="0">
<tbody>
<tr>
<td> </td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Q4/2017&quot;}">Q4/2017</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Q4/2016&quot;}">Q4/2016</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change&quot;}" data-sheets-numberformat="[null,2,&quot;\\+0.0;\\-0.0&quot;,1]">% Change</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2017}">2017</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2016}">2016</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change&quot;}" data-sheets-numberformat="[null,2,&quot;\\+0.0;\\-0.0&quot;,1]">% Change</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;AUSTRIA&quot;}">AUSTRIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1864}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,864</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1270}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,270</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:46.77165354330708}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">46.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7154}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,154</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:5068}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">5,068</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:41.16022099447514}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">41.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;BELGIUM&quot;}">BELGIUM</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3752}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,752</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2301}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,301</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:63.05953933072577}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">63.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:14299}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">14,299</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:8984}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">8,984</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:59.16073018699911}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">59.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;BULGARIA&quot;}">BULGARIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:71}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">71</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">9</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:688.8888888888889}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">688.9</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:106}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">106</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">13</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:715.3846153846155}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">715.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;CZECH REPUBLIC&quot;}">CZECH REPUBLIC</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:73}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">73</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:70}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">70</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4.285714285714286}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">4.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:307}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">307</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:200}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">200</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:53.5}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">53.5</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;DENMARK&quot;}">DENMARK</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:731}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">731</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:850}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">850</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-14.000000000000002}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">-14.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1342}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,342</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1920}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,920</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-30.104166666666664}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">-30.1</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ESTONIA&quot;}">ESTONIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-33.33333333333333}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">-33.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:43}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">43</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:35}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">35</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:22.857142857142858}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">22.9</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;FINLAND&quot;}">FINLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:969}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">969</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:413}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">413</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:134.62469733656175}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">134.6</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3055}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,055</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1430}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,430</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:113.63636363636364}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">113.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;FRANCE&quot;}">FRANCE</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:10254}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">10,254</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7525}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,525</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:36.26578073089701}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">36.3</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:36835}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">36,835</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:29194}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">29,194</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:26.173186271151604}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">26.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;GERMANY&quot;}">GERMANY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:17694}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">17,694</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:8087}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">8,087</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:118.79559787312972}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">118.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:54617}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">54,617</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:25214}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">25,214</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:116.61378599190925}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">116.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;GREECE&quot;}">GREECE</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:69}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">69</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1050}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">1050.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:199}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">199</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:43}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">43</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:362.7906976744186}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">362.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;HUNGARY&quot;}">HUNGARY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:461}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">461</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:109}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">109</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:322.9357798165138}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">322.9</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1192}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,192</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:343}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">343</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:247.52186588921285}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">247.5</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;IRELAND&quot;}">IRELAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:72}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">72</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:36}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">36</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:100}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">100.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:948}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">948</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:690}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">690</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:37.391304347826086}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">37.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ITALY&quot;}">ITALY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1315}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,315</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:770}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">770</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:70.77922077922078}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">70.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4827}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,827</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2819}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,819</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:71.23093295494857}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">71.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LATVIA&quot;}">LATVIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">11</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:8}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:37.5}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">37.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:56}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">56</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:40}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">40</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:40}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">40.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LITHUANIA&quot;}">LITHUANIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">15</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">11</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:36.36363636363637}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">36.4</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:52}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">52</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:64}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">64</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-18.75}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">-18.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;NETHERLANDS&quot;}">NETHERLANDS</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3517}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,517</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:14723}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">14,723</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-76.11220539292263}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">-76.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11079}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">11,079</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:22939}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">22,939</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-51.70234099132481}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">-51.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;POLAND&quot;}">POLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:369}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">369</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:150}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">150</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:146}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">146.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1068}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,068</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:569}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">569</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:87.69771528998243}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">87.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;PORTUGAL &quot;}">PORTUGAL</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1462}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,462</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:548}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">548</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:166.7883211678832}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">166.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4082}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">4,082</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1845}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,845</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:121.24661246612467}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">121.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ROMANIA&quot;}">ROMANIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:91}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">91</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">51</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:78.43137254901961}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">78.4</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:188}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">188</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:74}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">74</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:154.05405405405406}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">154.1</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SLOVAKIA&quot;}">SLOVAKIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:80}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">80</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:22}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">22</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:263.6363636363636}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">263.6</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:209}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">209</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:59}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">59</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:254.23728813559322}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">254.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SLOVENIA&quot;}">SLOVENIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:155}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">155</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:61}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">61</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:154.0983606557377}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">154.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:456}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">456</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:198}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">198</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:130.3030303030303}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">130.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SPAIN&quot;}">SPAIN</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2871}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,871</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1154}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,154</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:148.78682842287697}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">148.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7476}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,476</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3654}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,654</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:104.59770114942528}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">104.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SWEDEN&quot;}">SWEDEN</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6684}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6,684</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3887}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,887</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:71.95780807820941}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">72.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:19678}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">19,678</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13260}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">13,260</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:48.40120663650075}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">48.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;UNITED KINGDOM&quot;}">UNITED KINGDOM</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11863}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">11,863</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7835}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">7,835</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51.41033822590938}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">51.4</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:47298}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">47,298</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:37102}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">37,102</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:27.480998328931054}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">27.5</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EUROPEAN UNION&quot;}">EUROPEAN UNION</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:64447}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">64,447</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:49902}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">49,902</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:29.147128371608353}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">29.1</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:216566}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">216,566</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:155757}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">155,757</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:39.04094198013573}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">39.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU15&quot;}">EU15</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:63117}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">63,117</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:49405}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">49,405</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:27.754275883007796}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">27.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:212889}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">212,889</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:154162}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">154,162</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:38.09434231522684}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">38.1</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU (New Members)&quot;}">EU (New Members)</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1330}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,330</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:497}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">497</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:167.6056338028169}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">167.6</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3677}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">3,677</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1595}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,595</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:130.5329153605016}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">130.5</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;NORWAY&quot;}">NORWAY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:19217}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">19,217</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11522}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">11,522</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:66.78528033327548}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">66.8</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:62313}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">62,313</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:44908}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">44,908</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:38.75701434042932}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">38.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SWITZERLAND&quot;}">SWITZERLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2824}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">2,824</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1715}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">1,715</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:64.66472303206997}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">64.7</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:8391}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">8,391</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:6403}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">6,403</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:31.04794627518351}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">31.0</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EFTA&quot;}">EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:22041}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">22,041</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13237}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">13,237</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:66.51053864168618}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">66.5</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:70704}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">70,704</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:51311}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">51,311</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:37.79501471419383}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">37.8</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU + EFTA&quot;}">EU + EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:86488}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">86,488</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:63139}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">63,139</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:36.98031327705539}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">37.0</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:287270}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">287,270</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:207068}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">207,068</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:38.732203913690185}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">38.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU15 + EFTA&quot;}">EU15 + EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:85158}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">85,158</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:62642}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">62,642</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:35.943935378819326}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">35.9</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:283593}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">283,593</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:205473}" data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]">205,473</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:38.0195938152458}" data-sheets-numberformat="[null,2,&quot;0.0&quot;,1]">38.0</td>
</tr>
<tr>
<td> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
<td data-sheets-numberformat="[null,2,&quot;#,##0&quot;,1]"> </td>
</tr>
</tbody>
</table>'''

# %%
rows = re.split('<tr>', all_electric)

# %%
# general description, can be discarded
rows[0]
# Out:
# '<h2>The European Electric Car Market in 2017 (Full Year)</h2>\n<p>New electrically chargeable vehicle (ECV) registrations in the European Union (EU) and EFTA countries increased by 38.7% to 287,270 cars. During the fourth quarter 2017, the increase was slightly weaker at 37% to just over 86,000 electric cars.</p>\n<p>Despite the strong growth in electric car sales in Europe in 2017, electrically chargeable vehicles still have a market share of only 1.4%, which is around one in 60 new cars.</p>\n<ul>\n<li><strong>Note:</strong> Terminology used in these <a href="http://www.acea.be">ACEA</a> statistics: Electrically chargeable vehicle (ECV) = battery electric vehicles (BEV) + extended-range electric vehicles (EREV) + fuel cell electric vehicles (FCEV) + plug-in hybrid electric vehicles (PHEV).</li>\n</ul>\n<h2>Electric Car Sales Per European Union and EFTA Country in 2017 (Q1-Q4)</h2>\n<p>Registrations of electrically chargeable vehicles (ECV) in European Union and EFTA member countri
# ...

# %%
# column names
rows[1]
# Out:
# '\n<td> </td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Q4/2017&quot;}">Q4/2017</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Q4/2016&quot;}">Q4/2016</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change&quot;}" data-sheets-numberformat="[null,2,&quot;\\+0.0;\\-0.0&quot;,1]">% Change</td>\n<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2017}">2017</td>\n<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2016}">2016</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change&quot;}" data-sheets-numberformat="[null,2,&quot;\\+0.0;\\-0.0&quot;,1]">% Change</td>\n</tr>\n'

# %%
ae_rows = []

for row in rows[1:]:
    regex = re.findall('>(.+?)</td>', row, re.DOTALL)
    print(regex) # gets everything between the <td></td> tags, including line breaks
    ae_rows.append(regex)
# Out:
# [' ', 'Q4/2017', 'Q4/2016', '% Change', '2017', '2016', '% Change']
# ['AUSTRIA', '1,864', '1,270', '46.8', '7,154', '5,068', '41.2']
# ['BELGIUM', '3,752', '2,301', '63.1', '14,299', '8,984', '59.2']
# ['BULGARIA', '71', '9', '688.9', '106', '13', '715.4']
# ['CZECH REPUBLIC', '73', '70', '4.3', '307', '200', '53.5']
# ['DENMARK', '731', '850', '-14.0', '1,342', '1,920', '-30.1']
# ['ESTONIA', '4', '6', '-33.3', '43', '35', '22.9']
# ['FINLAND', '969', '413', '134.6', '3,055', '1,430', '113.6']
# ['FRANCE', '10,254', '7,525', '36.3', '36,835', '29,194', '26.2']
# ['GERMANY', '17,694', '8,087', '118.8', '54,617', '25,214', '116.6']
# ['GREECE', '69', '6', '1050.0', '199', '43', '362.8']
# ['HUNGARY', '461', '109', '322.9', '1,192', '343', '247.5']
# ['IRELAND', '72', '36', '100.0', '948', '690', '37.4']
# ['ITALY', '1,315', '770', '70.8', '4,827', '2,819', '71.2']
# ['LATVIA', '11', '8', '37.5', '56', '40', '40.0']
# ['LITHUANIA', '15', '11', '36.4', '52', '64', '-18.8']
# ...

# %%
ae_rows[1:-2]
# Out:
# [['AUSTRIA', '1,864', '1,270', '46.8', '7,154', '5,068', '41.2'],
#  ['BELGIUM', '3,752', '2,301', '63.1', '14,299', '8,984', '59.2'],
#  ['BULGARIA', '71', '9', '688.9', '106', '13', '715.4'],
#  ['CZECH REPUBLIC', '73', '70', '4.3', '307', '200', '53.5'],
#  ['DENMARK', '731', '850', '-14.0', '1,342', '1,920', '-30.1'],
#  ['ESTONIA', '4', '6', '-33.3', '43', '35', '22.9'],
#  ['FINLAND', '969', '413', '134.6', '3,055', '1,430', '113.6'],
#  ['FRANCE', '10,254', '7,525', '36.3', '36,835', '29,194', '26.2'],
#  ['GERMANY', '17,694', '8,087', '118.8', '54,617', '25,214', '116.6'],
#  ['GREECE', '69', '6', '1050.0', '199', '43', '362.8'],
#  ['HUNGARY', '461', '109', '322.9', '1,192', '343', '247.5'],
#  ['IRELAND', '72', '36', '100.0', '948', '690', '37.4'],
#  ['ITALY', '1,315', '770', '70.8', '4,827', '2,819', '71.2'],
#  ['LATVIA', '11', '8', '37.5', '56', '40', '40.0'],
#  ['LITHUANIA', '15', '11', '36.4', '52', '64', '-18.8'],
# ...

# %%
ecv_data = pd.DataFrame(columns = ['Country'] + ae_rows[0][1:])

# %%
ecv_data
# Out:
# Empty DataFrame
# Columns: [Country, Q4/2017, Q4/2016, % Change, 2017, 2016, % Change]
# Index: []

# %%
for i, row in enumerate(ae_rows[1:-2]):
    for j, col in enumerate(ecv_data.columns):
        ecv_data.loc[i, col] = row[j]

# %%
ecv_data
# Out:
#              Country Q4/2017 Q4/2016 % Change     2017     2016 % Change
# 0            AUSTRIA   1,864   1,270     41.2    7,154    5,068     41.2
# 1            BELGIUM   3,752   2,301     59.2   14,299    8,984     59.2
# 2           BULGARIA      71       9    715.4      106       13    715.4
# 3     CZECH REPUBLIC      73      70     53.5      307      200     53.5
# 4            DENMARK     731     850    -30.1    1,342    1,920    -30.1
# 5            ESTONIA       4       6     22.9       43       35     22.9
# 6            FINLAND     969     413    113.6    3,055    1,430    113.6
# 7             FRANCE  10,254   7,525     26.2   36,835   29,194     26.2
# 8            GERMANY  17,694   8,087    116.6   54,617   25,214    116.6
# 9             GREECE      69       6    362.8      199       43    362.8
# 10           HUNGARY     461     109    247.5    1,192      343    247.5
# 11           IRELAND      72      36     37.4      948      690     37.4
# ...

# %%
'''
further work:
- get all the electric vehicles sales for these years (BEVs, etc.) and calculate the shares of each type
- get the total volumes and calculate the ECV share in the total car sales volumes
'''

# %%
ecv_data = ecv_data.drop('% Change', axis = 1)

# %%
ecv_data.head()
# Out:
#           Country Q4/2017 Q4/2016    2017   2016
# 0         AUSTRIA   1,864   1,270   7,154  5,068
# 1         BELGIUM   3,752   2,301  14,299  8,984
# 2        BULGARIA      71       9     106     13
# 3  CZECH REPUBLIC      73      70     307    200
# 4         DENMARK     731     850   1,342  1,920

# %%
ecv_data = ecv_data.applymap(lambda x: x.replace(',',''))

# %%
ecv_data.head()
# Out:
#           Country Q4/2017 Q4/2016   2017  2016
# 0         AUSTRIA    1864    1270   7154  5068
# 1         BELGIUM    3752    2301  14299  8984
# 2        BULGARIA      71       9    106    13
# 3  CZECH REPUBLIC      73      70    307   200
# 4         DENMARK     731     850   1342  1920

# %%
for column in ecv_data.columns[1:]:
    ecv_data[column] = ecv_data[column].astype(int)

# %%
ecv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 5 columns):
# Country    31 non-null object
# Q4/2017    31 non-null int32
# Q4/2016    31 non-null int32
# 2017       31 non-null int32
# 2016       31 non-null int32
# dtypes: int32(4), object(1)
# memory usage: 2.2+ KB

# %%
ecv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 5 columns):
# Country    31 non-null object
# Q4/2017    31 non-null object
# Q4/2016    31 non-null object
# 2017       31 non-null object
# 2016       31 non-null object
# dtypes: object(5)
# memory usage: 2.7+ KB

# %%
# all new car sales in 2017

# %%
new_cars_2017 = '''<h2>Car Sales per European Union and EFTA Country in 2017</h2>
<p>New passenger vehicle registrations in 2017 were as follows per EU and EFTA country according to the <a href="http://www.acea.be">ACEA</a>:</p>
<table dir="ltr" border="0" cellspacing="0" cellpadding="0">
<tbody>
<tr>
<td></td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Sales 2017&quot;}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">Sales 2017</td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;Sales 2016&quot;}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}" data-sheets-formula="=HYPERLINK(&quot;https://www.best-selling-cars.com/europe/2016-full-year-europe-car-sales-per-eu-efta-country/&quot;,&quot;Sales 2016&quot;)"><a class="in-cell-link" href="https://www.best-selling-cars.com/europe/2016-full-year-europe-car-sales-per-eu-efta-country/" target="_blank" rel="noopener">Sales 2016</a></td>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;% Change 16/17&quot;}">
<div>
<div>% Change 16/17</div>
</div>
</td>
</tr>
<tr>
<td></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td></td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EU + EFTA&quot;}">EU + EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15631687}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">15,631,687</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15131778}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">15,131,778</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3.3}" data-sheets-formula="=+3.3">3.3</td>
</tr>
<tr>
<td></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td></td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;AUSTRIA&quot;}">AUSTRIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:353320}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">353,320</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:329604}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">329,604</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7.2}" data-sheets-formula="=+7.2">7.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;BELGIUM&quot;}">BELGIUM</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:546558}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">546,558</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:539519}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">539,519</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1.3}" data-sheets-formula="=+1.3">1.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;BULGARIA&quot;}">BULGARIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:31244}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">31,244</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:26370}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">26,370</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:18.5}" data-sheets-formula="=+18.5">18.5</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;CROATIA&quot;}">CROATIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:50412}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">50,412</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:43015}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">43,015</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:17.2}" data-sheets-formula="=+17.2">17.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;CYPRUS&quot;}">CYPRUS</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:13080}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">13,080</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:12671}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">12,671</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3.2}" data-sheets-formula="=+3.2">3.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;CZECH REPUBLIC&quot;}">CZECH REPUBLIC</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:271595}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">271,595</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:259693}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">259,693</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4.6}" data-sheets-formula="=+4.6">4.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;DENMARK&quot;}">DENMARK</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:221818}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">221,818</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:222917}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">222,917</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-0.5}">-0.5</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ESTONIA&quot;}">ESTONIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:25020}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">25,020</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:22429}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">22,429</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11.6}" data-sheets-formula="=+11.6">11.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;FINLAND&quot;}">FINLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:118581}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">118,581</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:119000}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">119,000</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-0.4}">-0.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;FRANCE&quot;}">FRANCE</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2110748}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">2,110,748</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2015177}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">2,015,177</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4.7}" data-sheets-formula="=+4.7">4.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;GERMANY&quot;}">GERMANY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3441262}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">3,441,262</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3351607}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">3,351,607</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2.7}" data-sheets-formula="=+2.7">2.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;GREECE&quot;}">GREECE</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:88083}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">88,083</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:78873}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">78,873</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11.7}" data-sheets-formula="=+11.7">11.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;HUNGARY&quot;}">HUNGARY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:116265}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">116,265</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:96552}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">96,552</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:20.4}" data-sheets-formula="=+20.4">20.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;IRELAND&quot;}">IRELAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:131355}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">131,355</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:146649}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">146,649</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-10.4}">-10.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ITALY&quot;}">ITALY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1970497}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">1,970,497</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1825892}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">1,825,892</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7.9}" data-sheets-formula="=+7.9">7.9</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LATVIA&quot;}">LATVIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:16692}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">16,692</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:16359}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">16,359</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2}" data-sheets-formula="=+2">2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LITHUANIA&quot;}">LITHUANIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:25865}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">25,865</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:20320}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">20,320</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:27.3}" data-sheets-formula="=+27.3">27.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;LUXEMBOURG&quot;}">LUXEMBOURG</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:52775}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">52,775</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:50561}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">50,561</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:4.4}" data-sheets-formula="=+4.4">4.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;NETHERLANDS&quot;}">NETHERLANDS</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:417075}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">417,075</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:381885}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">381,885</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9.2}" data-sheets-formula="=+9.2">9.2</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;POLAND&quot;}">POLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:486352}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">486,352</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:416123}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">416,123</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:16.9}" data-sheets-formula="=+16.9">16.9</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;PORTUGAL&quot;}">PORTUGAL</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:222134}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">222,134</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:207330}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">207,330</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7.1}" data-sheets-formula="=+7.1">7.1</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ROMANIA&quot;}">ROMANIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:105083}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">105,083</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:94919}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">94,919</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:10.7}" data-sheets-formula="=+10.7">10.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SLOVAKIA&quot;}">SLOVAKIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:96085}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">96,085</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:88163}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">88,163</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:9}" data-sheets-formula="=+9">9</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SLOVENIA&quot;}">SLOVENIA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:70892}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">70,892</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:63674}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">63,674</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:11.3}" data-sheets-formula="=+11.3">11.3</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SPAIN&quot;}">SPAIN</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1234931}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">1,234,931</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1147009}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">1,147,009</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:7.7}" data-sheets-formula="=+7.7">7.7</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SWEDEN&quot;}">SWEDEN</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:379393}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">379,393</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:372318}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">372,318</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:1.9}" data-sheets-formula="=+1.9">1.9</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;UNITED KINGDOM&quot;}">UNITED KINGDOM</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2540617}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">2,540,617</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2692786}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">2,692,786</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-5.7}">-5.7</td>
</tr>
<tr>
<td></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td></td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EUROPEAN UNION&quot;}">EUROPEAN UNION</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15137732}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">15,137,732</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:14641415}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">14,641,415</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:3.4}" data-sheets-formula="=+3.4">3.4</td>
</tr>
<tr>
<td></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td></td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;ICELAND&quot;}">ICELAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:21277}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">21,277</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:18442}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">18,442</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:15.4}" data-sheets-formula="=+15.4">15.4</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;NORWAY&quot;}">NORWAY</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:158650}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">158,650</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:154603}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">154,603</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:2.6}" data-sheets-formula="=+2.6">2.6</td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;SWITZERLAND&quot;}">SWITZERLAND</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:314028}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">314,028</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:317318}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">317,318</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:-1}">-1</td>
</tr>
<tr>
<td></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td></td>
</tr>
<tr>
<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;EFTA&quot;}">EFTA</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:493955}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">493,955</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:490363}" data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}">490,363</td>
<td data-sheets-value="{&quot;1&quot;:3,&quot;3&quot;:0.7}" data-sheets-formula="=+0.7">0.7</td>
</tr>
<tr>
<td></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>
<td></td>
</tr>
</tbody>
</table>'''

# %%
newcar_rows = re.split('<tr>', new_cars_2017)

# %%
newcar_rows[4]
# Out:
# '\n<td></td>\n<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>\n<td data-sheets-numberformat="{&quot;1&quot;:2,&quot;2&quot;:&quot;#,##0&quot;,&quot;3&quot;:1}"></td>\n<td></td>\n</tr>\n'

# %%
# can't capture the first row correctly due to different table formatting
# [^\\n] escapes new line breaks
# it's important to escape plus AND minus signs!
# if we use + 

newcar_data = []

for row in newcar_rows[1:]:
    regex = re.findall('>([^\\n][\w\s\.\,\+\%\-]*)</t', row)
    if len(regex) > 0:
        print(regex)
        newcar_data.append(regex)
# Out:
# ['Sales 2017']
# ['EU + EFTA', '15,631,687', '15,131,778', '3.3']
# ['AUSTRIA', '353,320', '329,604', '7.2']
# ['BELGIUM', '546,558', '539,519', '1.3']
# ['BULGARIA', '31,244', '26,370', '18.5']
# ['CROATIA', '50,412', '43,015', '17.2']
# ['CYPRUS', '13,080', '12,671', '3.2']
# ['CZECH REPUBLIC', '271,595', '259,693', '4.6']
# ['DENMARK', '221,818', '222,917', '-0.5']
# ['ESTONIA', '25,020', '22,429', '11.6']
# ['FINLAND', '118,581', '119,000', '-0.4']
# ['FRANCE', '2,110,748', '2,015,177', '4.7']
# ['GERMANY', '3,441,262', '3,351,607', '2.7']
# ['GREECE', '88,083', '78,873', '11.7']
# ['HUNGARY', '116,265', '96,552', '20.4']
# ['IRELAND', '131,355', '146,649', '-10.4']
# ['ITALY', '1,970,497', '1,825,892', '7.9']
# ['LATVIA', '16,692', '16,359', '2']
# ['LITHUANIA', '25,865', '20,320', '27.3']
# ['LUXEMBOURG', '52,775', '50,561', '4.4']
# ['NETHERLANDS', '417,075', '381,885', '9.2']
# ['POLAND', '486,352', '416,123', '16.9']
# ['PORTUGAL', '222,134', '207,330', '7.1']
# ...

# %%
newcars_2017 = pd.DataFrame(columns = ['Country', 'Sales 2017', 'Sales 2016', 'change'])

# %%
newcars_2017
# Out:
# Empty DataFrame
# Columns: [Country, Sales 2017, Sales 2016, change]
# Index: []

# %%
for i, row in enumerate(newcar_data[1:]):
    for j, col in enumerate(newcars_2017.columns):
        newcars_2017.loc[i, col] = row[j]

# %%
newcars_2017
# Out:
#            Country  Sales 2017  Sales 2016 change
# 0        EU + EFTA  15,631,687  15,131,778    3.3
# 1          AUSTRIA     353,320     329,604    7.2
# 2          BELGIUM     546,558     539,519    1.3
# 3         BULGARIA      31,244      26,370   18.5
# 4          CROATIA      50,412      43,015   17.2
# 5           CYPRUS      13,080      12,671    3.2
# 6   CZECH REPUBLIC     271,595     259,693    4.6
# 7          DENMARK     221,818     222,917   -0.5
# 8          ESTONIA      25,020      22,429   11.6
# 9          FINLAND     118,581     119,000   -0.4
# 10          FRANCE   2,110,748   2,015,177    4.7
# 11         GERMANY   3,441,262   3,351,607    2.7
# 12          GREECE      88,083      78,873   11.7
# 13         HUNGARY     116,265      96,552   20.4
# 14         IRELAND     131,355     146,649  -10.4
# 15           ITALY   1,970,497   1,825,892    7.9
# 16          LATVIA      16,692      16,359      2
# 17       LITHUANIA      25,865      20,320   27.3
# ...

# %%
newcars_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 4 columns):
# Country       33 non-null object
# Sales 2017    33 non-null object
# Sales 2016    33 non-null object
# change        33 non-null object
# dtypes: object(4)
# memory usage: 2.5+ KB

# %%
newcars_2017 = newcars_2017.drop('change', axis = 1)

# %%
newcars_2017 = newcars_2017.applymap(lambda x: x.replace(',',''))

# %%
for col in ['Sales 2017', 'Sales 2016']:
    newcars_2017[col] = newcars_2017[col].astype(int)

# %%
newcars_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 3 columns):
# Country       33 non-null object
# Sales 2017    33 non-null int32
# Sales 2016    33 non-null int32
# dtypes: int32(2), object(1)
# memory usage: 2.0+ KB

# %%
ecv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 5 columns):
# Country    31 non-null object
# Q4/2017    31 non-null int32
# Q4/2016    31 non-null int32
# 2017       31 non-null int32
# 2016       31 non-null int32
# dtypes: int32(4), object(1)
# memory usage: 2.2+ KB

# %%
ecv_europe = pd.merge(newcars_2017, ecv_data, how = 'inner', on = 'Country')

# %%
ecv_europe
# Out:
#            Country  Sales 2017  Sales 2016  Q4/2017  Q4/2016    2017    2016
# 0        EU + EFTA    15631687    15131778    86488    63139  287270  207068
# 1          AUSTRIA      353320      329604     1864     1270    7154    5068
# 2          BELGIUM      546558      539519     3752     2301   14299    8984
# 3         BULGARIA       31244       26370       71        9     106      13
# 4   CZECH REPUBLIC      271595      259693       73       70     307     200
# 5          DENMARK      221818      222917      731      850    1342    1920
# 6          ESTONIA       25020       22429        4        6      43      35
# 7          FINLAND      118581      119000      969      413    3055    1430
# 8           FRANCE     2110748     2015177    10254     7525   36835   29194
# 9          GERMANY     3441262     3351607    17694     8087   54617   25214
# 10          GREECE       88083       78873       69        6     199      43
# ...

# %%
for year in [2016, 2017]:
    ecv_europe['ECV share {} [%]'.format(year)] = ecv_europe['{}'.format(year)]/ecv_europe['Sales {}'.format(year)]*100

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017  Sales 2016  Q4/2017  Q4/2016    2017    2016  \
# 0       EU + EFTA    15631687    15131778    86488    63139  287270  207068
# 1         AUSTRIA      353320      329604     1864     1270    7154    5068
# 2         BELGIUM      546558      539519     3752     2301   14299    8984
# 3        BULGARIA       31244       26370       71        9     106      13
# 4  CZECH REPUBLIC      271595      259693       73       70     307     200
#
#    ECV share 2016 [%]  ECV share 2017 [%]
# 0            1.368431            1.837742
# 1            1.537603            2.024793
# 2            1.665187            2.616191
# 3            0.049298            0.339265
# 4            0.077014            0.113036

# %%
for year in [2016, 2017]:
    ecv_europe.drop('Q4/{}'.format(year), axis = 1, inplace = True)

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017  Sales 2016    2017    2016  ECV share 2016 [%]  \
# 0       EU + EFTA    15631687    15131778  287270  207068            1.368431
# 1         AUSTRIA      353320      329604    7154    5068            1.537603
# 2         BELGIUM      546558      539519   14299    8984            1.665187
# 3        BULGARIA       31244       26370     106      13            0.049298
# 4  CZECH REPUBLIC      271595      259693     307     200            0.077014
#
#    ECV share 2017 [%]
# 0            1.837742
# 1            2.024793
# 2            2.616191
# 3            0.339265
# 4            0.113036

# %%
for year in [2016, 2017]:
    ecv_europe['ECV share {} [%]'.format(year)] = ecv_europe['ECV share {} [%]'.format(year)].round(2)

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017  Sales 2016    2017    2016  ECV share 2016 [%]  \
# 0       EU + EFTA    15631687    15131778  287270  207068                1.37
# 1         AUSTRIA      353320      329604    7154    5068                1.54
# 2         BELGIUM      546558      539519   14299    8984                1.67
# 3        BULGARIA       31244       26370     106      13                0.05
# 4  CZECH REPUBLIC      271595      259693     307     200                0.08
#
#    ECV share 2017 [%]
# 0                1.84
# 1                2.02
# 2                2.62
# 3                0.34
# 4                0.11

# %%
ecv_europe = ecv_europe[['Country', 'Sales 2017', '2017', 'ECV share 2017 [%]', 'Sales 2016', '2016', 'ECV share 2016 [%]']]

# %%
ecv_europe
# Out:
#            Country  Sales 2017    2017  ECV share 2017 [%]  Sales 2016  \
# 0        EU + EFTA    15631687  287270                1.84    15131778
# 1          AUSTRIA      353320    7154                2.02      329604
# 2          BELGIUM      546558   14299                2.62      539519
# 3         BULGARIA       31244     106                0.34       26370
# 4   CZECH REPUBLIC      271595     307                0.11      259693
# 5          DENMARK      221818    1342                0.61      222917
# 6          ESTONIA       25020      43                0.17       22429
# 7          FINLAND      118581    3055                2.58      119000
# 8           FRANCE     2110748   36835                1.75     2015177
# 9          GERMANY     3441262   54617                1.59     3351607
# 10          GREECE       88083     199                0.23       78873
# 11         HUNGARY      116265    1192                1.03       96552
# ...

# %%
ecvtable_2018 = '''
<h2>Electric Car Sales per European Union and EFTA Country in 2018 (Q1-Q4)</h2>
<p>New passenger vehicle registrations of electrically chargeable vehicles (ECV) in European Union and EFTA countries during Q4/2018 and the full calendar year 2018 were as follows according to the <a href="https://www.acea.be/">ACEA</a>:</p>
<table class="wp-block-table is-style-stripes"><tbody><tr><td>&#8211;</td><td>Q4/2018</td><td>Q4/2017</td><td>% Change</td><td>FY 2018</td><td><a href="https://www.best-selling-cars.com/europe/2017-full-year-europe-electric-hybrid-vehicle-sales-per-eu-efta-country/" target="_blank" rel="noreferrer noopener">FY2017</a></td><td>% Change</td></tr><tr><td>AUSTRIA</td><td>2,527</td><td>1,864</td><td>35.6</td><td>8,652</td><td>7,154</td><td>20.9</td></tr><tr><td>BELGIUM</td><td>2,845</td><td>3,752</td><td>-24.2</td><td>13,353</td><td>14,459</td><td>-7.6</td></tr><tr><td>BULGARIA</td><td>87</td><td>71</td><td>22.5</td><td>220</td><td>106</td><td>107.5</td></tr><tr><td>CZECH REPUBLIC</td><td>281</td><td>93</td><td>202.2</td><td>981</td><td>387</td><td>153.5</td></tr><tr><td>DENMARK</td><td>1,098</td><td>721</td><td>52.3</td><td>4,679</td><td>1,334</td><td>250.7</td></tr><tr><td>ESTONIA</td><td>29</td><td>6</td><td>383.3</td><td>118</td><td>46</td><td>156.5</td></tr><tr><td>FINLAND</td><td>1,214</td><td>969</td><td>25.3</td><td>5,708</td><td>3,055</td><td>86.8</td></tr><tr><td>FRANCE</td><td>14,510</td><td>10,254</td><td>41.5</td><td>45,623</td><td>36,835</td><td>23.9</td></tr><tr><td>GERMANY</td><td>17,413</td><td>17,694</td><td>-1.6</td><td>67,658</td><td>54,617</td><td>23.9</td></tr><tr><td>GREECE</td><td>84</td><td>66</td><td>27.3</td><td>315</td><td>191</td><td>64.9</td></tr><tr><td>HUNGARY</td><td>613</td><td>461</td><td>33.0</td><td>2,070</td><td>1,192</td><td>73.7</td></tr><tr><td>IRELAND</td><td>113</td><td>72</td><td>56.9</td><td>1,972</td><td>948</td><td>108.0</td></tr><tr><td>ITALY</td><td>2,520</td><td>1,370</td><td>83.9</td><td>9,731</td><td>4,886</td><td>99.2</td></tr><tr><td>LATVIA</td><td>22</td><td>8</td><td>175.0</td><td>93</td><td>40</td><td>132.5</td></tr><tr><td>LITHUANIA</td><td>57</td><td>15</td><td>280.0</td><td>143</td><td>52</td><td>175.0</td></tr><tr><td>NETHERLANDS</td><td>12,086</td><td>3,515</td><td>243.8</td><td>29,708</td><td>11,042</td><td>169.0</td></tr><tr><td>POLAND</td><td>365</td><td>377</td><td>-3.2</td><td>1,324</td><td>1,077</td><td>22.9</td></tr><tr><td>PORTUGAL </td><td>2,342</td><td>1,461</td><td>60.3</td><td>7,849</td><td>4,078</td><td>92.5</td></tr><tr><td>ROMANIA</td><td>137</td><td>91</td><td>50.5</td><td>605</td><td>188</td><td>221.8</td></tr><tr><td>SLOVAKIA</td><td>71</td><td>80</td><td>-11.3</td><td>293</td><td>209</td><td>40.2</td></tr><tr><td>SLOVENIA</td><td>159</td><td>155</td><td>2.6</td><td>663</td><td>456</td><td>45.4</td></tr><tr><td>SPAIN</td><td>4,352</td><td>2,861</td><td>52.1</td><td>11,810</td><td>7,448</td><td>58.6</td></tr><tr><td>SWEDEN</td><td>8,383</td><td>6,593</td><td>27.2</td><td>28,332</td><td>19,319</td><td>46.7</td></tr><tr><td>UNITED KINGDOM</td><td>15,064</td><td>12,354</td><td>21.9</td><td>59,947</td><td>49,217</td><td>21.8</td></tr><tr><td>EUROPEAN UNION</td><td>86,372</td><td>64,903</td><td>33.1</td><td>301,847</td><td>218,336</td><td>38.2</td></tr><tr><td>NORWAY</td><td>20,651</td><td>19,217</td><td>7.5</td><td>72,689</td><td>62,313</td><td>16.7</td></tr><tr><td>SWITZERLAND</td><td>3,025</td><td>2,842</td><td>6.4</td><td>9,516</td><td>8,423</td><td>13.0</td></tr><tr><td>EFTA</td><td>23,676</td><td>22,059</td><td>7.3</td><td>82,205</td><td>70,736</td><td>16.2</td></tr><tr><td>EU + EFTA</td><td>110,048</td><td>86,962</td><td>26.5</td><td>384,052</td><td>289,072</td><td>32.9</td></tr><tr><td><a href="https://www.acea.be/" target="_blank" rel="noreferrer noopener">Source: ACEA</a></td></tr></tbody></table>'''

# %%
ecvsales2018_rows = re.split('<tr>', ecvtable_2018)

# %%
re.split('<td>', ecvsales2018_rows[1])
# Out:
# ['',
#  '&#8211;</td>',
#  'Q4/2018</td>',
#  'Q4/2017</td>',
#  '% Change</td>',
#  'FY 2018</td>',
#  '<a href="https://www.best-selling-cars.com/europe/2017-full-year-europe-electric-hybrid-vehicle-sales-per-eu-efta-country/" target="_blank" rel="noreferrer noopener">FY2017</a></td>',
#  '% Change</td></tr>']

# %%
# can't really capture everything from the second row with column names
# 'FY 2017' has to be added manually

re.findall('>([^\\n][\w\s\.\,\+\%\-/]*)</td', ecvsales2018_rows[1])
# Out:
# ['Q4/2018', 'Q4/2017', '% Change', 'FY 2018', '% Change']

# %%
ecvsales2018_data = []

for row in ecvsales2018_rows[1:]:
    regex = re.findall('>([^\\n][\w\s\.\,\+\%\-/]*)</t', row)
    if len(regex) > 0:
        print(regex)
        ecvsales2018_data.append(regex)
# Out:
# ['Q4/2018', 'Q4/2017', '% Change', 'FY 2018', '% Change']
# ['AUSTRIA', '2,527', '1,864', '35.6', '8,652', '7,154', '20.9']
# ['BELGIUM', '2,845', '3,752', '-24.2', '13,353', '14,459', '-7.6']
# ['BULGARIA', '87', '71', '22.5', '220', '106', '107.5']
# ['CZECH REPUBLIC', '281', '93', '202.2', '981', '387', '153.5']
# ['DENMARK', '1,098', '721', '52.3', '4,679', '1,334', '250.7']
# ['ESTONIA', '29', '6', '383.3', '118', '46', '156.5']
# ['FINLAND', '1,214', '969', '25.3', '5,708', '3,055', '86.8']
# ['FRANCE', '14,510', '10,254', '41.5', '45,623', '36,835', '23.9']
# ['GERMANY', '17,413', '17,694', '-1.6', '67,658', '54,617', '23.9']
# ['GREECE', '84', '66', '27.3', '315', '191', '64.9']
# ['HUNGARY', '613', '461', '33.0', '2,070', '1,192', '73.7']
# ['IRELAND', '113', '72', '56.9', '1,972', '948', '108.0']
# ['ITALY', '2,520', '1,370', '83.9', '9,731', '4,886', '99.2']
# ['LATVIA', '22', '8', '175.0', '93', '40', '132.5']
# ['LITHUANIA', '57', '15', '280.0', '143', '52', '175.0']
# ...

# %%
ecvsales2018_data[0][:-2]
# Out:
# ['Q4/2018', 'Q4/2017', '% Change']

# %%
# make the column list from four separate lists

ecvsales2018 = pd.DataFrame(columns = ['Country'] + ecvsales2018_data[0][:-1] + ['FY 2017'] + ecvsales2018_data[0][-1:])

# %%
ecvsales2018
# Out:
# Empty DataFrame
# Columns: [Country, Q4/2018, Q4/2017, % Change, FY 2018, FY 2017, % Change]
# Index: []

# %%
for i, row in enumerate(ecvsales2018_data[1:]):
    for j, col in enumerate(ecvsales2018.columns):
        ecvsales2018.loc[i, col] = row[j]

# %%
ecvsales2018
# Out:
#            Country  Q4/2018 Q4/2017 % Change  FY 2018  FY 2017 % Change
# 0          AUSTRIA    2,527   1,864     20.9    8,652    7,154     20.9
# 1          BELGIUM    2,845   3,752     -7.6   13,353   14,459     -7.6
# 2         BULGARIA       87      71    107.5      220      106    107.5
# 3   CZECH REPUBLIC      281      93    153.5      981      387    153.5
# 4          DENMARK    1,098     721    250.7    4,679    1,334    250.7
# 5          ESTONIA       29       6    156.5      118       46    156.5
# 6          FINLAND    1,214     969     86.8    5,708    3,055     86.8
# 7           FRANCE   14,510  10,254     23.9   45,623   36,835     23.9
# 8          GERMANY   17,413  17,694     23.9   67,658   54,617     23.9
# 9           GREECE       84      66     64.9      315      191     64.9
# 10         HUNGARY      613     461     73.7    2,070    1,192     73.7
# 11         IRELAND      113      72    108.0    1,972      948    108.0
# ...

# %%
# extract only the country and sales volumes columns

ecvsales2018 = ecvsales2018[[ecvsales2018.columns[0]] + [ecvsales2018.columns[-3]] + [ecvsales2018.columns[-2]]]

# %%
ecvsales2018 = ecvsales2018.applymap(lambda x: x.replace(',', ''))

# %%
for year in [2017, 2018]:
    ecvsales2018['FY {}'.format(year)] = ecvsales2018['FY {}'.format(year)].astype(int)

# %%
# in some countries there are slight differences between the 2017 ECV sales volumes; which should we keep? 
# probably the FY2017 values from the 2018 are more accurate

ecv_europe = ecv_europe.merge(ecvsales2018, how = 'inner', on = 'Country')

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017    2017  ECV share 2017 [%]  Sales 2016    2016  \
# 0       EU + EFTA    15631687  287270                1.84    15131778  207068
# 1         AUSTRIA      353320    7154                2.02      329604    5068
# 2         BELGIUM      546558   14299                2.62      539519    8984
# 3        BULGARIA       31244     106                0.34       26370      13
# 4  CZECH REPUBLIC      271595     307                0.11      259693     200
#
#    ECV share 2016 [%]  FY 2018  FY 2017
# 0                1.37   384052   289072
# 1                1.54     8652     7154
# 2                1.67    13353    14459
# 3                0.05      220      106
# 4                0.08      981      387

# %%
ecv_europe = ecv_europe.rename(columns = {'FY 2018':'ECV Sales 2018', 'FY 2017':'ECV Sales 2017', '2016':'ECV Sales 2016'})

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017    2017  ECV share 2017 [%]  Sales 2016  \
# 0       EU + EFTA    15631687  287270                1.84    15131778
# 1         AUSTRIA      353320    7154                2.02      329604
# 2         BELGIUM      546558   14299                2.62      539519
# 3        BULGARIA       31244     106                0.34       26370
# 4  CZECH REPUBLIC      271595     307                0.11      259693
#
#    ECV Sales 2016  ECV share 2016 [%]  ECV Sales 2018  ECV Sales 2017
# 0          207068                1.37          384052          289072
# 1            5068                1.54            8652            7154
# 2            8984                1.67           13353           14459
# 3              13                0.05             220             106
# 4             200                0.08             981             387

# %%
ecv_europe.drop('2017', axis = 1, inplace = True)

# %%
eurosales2018_table = '''<h2>Car Sales per European Union and EFTA Country in 2018</h2>
<p>New passenger vehicle registrations in the various European Union (EU) and EFTA countries during the full calendar year 2018 were as follows according to the ACEA:</p>
<table class="wp-block-table is-style-stripes"><tbody><tr><td>Country:</td><td>FY 2018</td><td><a href="https://www.best-selling-cars.com/europe/2017-full-year-europe-car-sales-per-eu-efta-country/" target="_blank" rel="noreferrer noopener">FY2017</a></td><td>% Change</td></tr><tr><td>AUSTRIA</td><td>341,068</td><td>353,320</td><td>-3.5</td></tr><tr><td>BELGIUM</td><td>549,632</td><td>546,558</td><td>+0.6</td></tr><tr><td>BULGARIA</td><td>34,332</td><td>31,244</td><td>+9.9</td></tr><tr><td>CROATIA</td><td>59,856</td><td>50,412</td><td>+18.7</td></tr><tr><td>CYPRUS</td><td>12,956</td><td>13,080</td><td>-0.9</td></tr><tr><td>CZECH REPUBLIC</td><td>261,437</td><td>271,595</td><td>-3.7</td></tr><tr><td>DENMARK</td><td>218,565</td><td>221,838</td><td>-1.5</td></tr><tr><td>ESTONIA</td><td>25,387</td><td>24,494</td><td>+3.6</td></tr><tr><td>FINLAND</td><td>120,499</td><td>118,587</td><td>+1.6</td></tr><tr><td>FRANCE</td><td>2,173,481</td><td>2,110,748</td><td>+3.0</td></tr><tr><td>GERMANY</td><td>3,435,778</td><td>3,441,262</td><td>-0.2</td></tr><tr><td>GREECE</td><td>103,431</td><td>88,083</td><td>+17.4</td></tr><tr><td>HUNGARY</td><td>136,594</td><td>116,265</td><td>+17.5</td></tr><tr><td>IRELAND</td><td>125,557</td><td>131,332</td><td>-4.4</td></tr><tr><td>ITALY</td><td>1,910,025</td><td>1,971,345</td><td>-3.1</td></tr><tr><td>LATVIA</td><td>16,879</td><td>16,692</td><td>+1.1</td></tr><tr><td>LITHUANIA2</td><td>32,447</td><td>25,867</td><td>+25.4</td></tr><tr><td>LUXEMBOURG</td><td>52,811</td><td>52,775</td><td>+0.1</td></tr><tr><td>NETHERLANDS</td><td>443,812</td><td>414,306</td><td>+7.1</td></tr><tr><td>POLAND</td><td>531,889</td><td>486,352</td><td>+9.4</td></tr><tr><td>PORTUGAL</td><td>228,290</td><td>222,129</td><td>+2.8</td></tr><tr><td>ROMANIA</td><td>130,919</td><td>106,387</td><td>+23.1</td></tr><tr><td>SLOVAKIA</td><td>98,080</td><td>96,085</td><td>+2.1</td></tr><tr><td>SLOVENIA</td><td>72,835</td><td>70,892</td><td>+2.7</td></tr><tr><td>SPAIN</td><td>1,321,438</td><td>1,234,932</td><td>+7.0</td></tr><tr><td>SWEDEN</td><td>353,729</td><td>379,393</td><td>-6.8</td></tr><tr><td>UNITED KINGDOM</td><td>2,367,147</td><td>2,540,617</td><td>-6.8</td></tr><tr><td>EUROPEAN UNION*</td><td>15,158,874</td><td>15,136,590</td><td>+0.1</td></tr><tr><td>&#8211;</td></tr><tr><td>ICELAND</td><td>17,967</td><td>21,287</td><td>-15.6</td></tr><tr><td>NORWAY</td><td>147,929</td><td>158,650</td><td>-6.8</td></tr><tr><td>SWITZERLAND</td><td>299,716</td><td>314,028</td><td>-4.6</td></tr><tr><td>EFTA</td><td>465,612</td><td>493,965</td><td>-5.7</td></tr><tr><td>&#8211;</td></tr><tr><td><strong>EU* + EFTA</strong></td><td><strong>15,624,486</strong></td><td><strong>15,630,555</strong></td><td><strong>-0.04</strong></td></tr><tr><td><a href="http://acea.be" target="_blank" rel="noreferrer noopener">Source: ACEA</a></td><td></td></tr><tr><td>*Excluding Malta</td><td></td></tr></tbody></table>'''

# %%
eurosales2018_rows = re.split('<tr>', eurosales2018_table)

# %%
re.findall('>([^\\n][\w\s\.\,\+\%\-/]*)</', eurosales2018_rows[1])
# Out:
# ['FY 2018', 'FY2017', '% Change']

# %%
re.findall('>([^\\n][\w\s\.\,\+\%\-/]*)</td', eurosales2018_rows[2])
# Out:
# ['AUSTRIA', '341,068', '353,320', '-3.5']

# %%
# added * to regex for "special" cases like 'EU* + EFTA'

eurosales2018_data = []

for row in eurosales2018_rows[1:]:
    regex = re.findall('>([^\\n][\w\s\.\,\+\%\-/\*]*)</', row)
    if len(regex) > 0:
        print(regex)
        eurosales2018_data.append(regex)
# Out:
# ['FY 2018', 'FY2017', '% Change']
# ['AUSTRIA', '341,068', '353,320', '-3.5']
# ['BELGIUM', '549,632', '546,558', '+0.6']
# ['BULGARIA', '34,332', '31,244', '+9.9']
# ['CROATIA', '59,856', '50,412', '+18.7']
# ['CYPRUS', '12,956', '13,080', '-0.9']
# ['CZECH REPUBLIC', '261,437', '271,595', '-3.7']
# ['DENMARK', '218,565', '221,838', '-1.5']
# ['ESTONIA', '25,387', '24,494', '+3.6']
# ['FINLAND', '120,499', '118,587', '+1.6']
# ['FRANCE', '2,173,481', '2,110,748', '+3.0']
# ['GERMANY', '3,435,778', '3,441,262', '-0.2']
# ['GREECE', '103,431', '88,083', '+17.4']
# ['HUNGARY', '136,594', '116,265', '+17.5']
# ['IRELAND', '125,557', '131,332', '-4.4']
# ['ITALY', '1,910,025', '1,971,345', '-3.1']
# ['LATVIA', '16,879', '16,692', '+1.1']
# ['LITHUANIA2', '32,447', '25,867', '+25.4']
# ['LUXEMBOURG', '52,811', '52,775', '+0.1']
# ['NETHERLANDS', '443,812', '414,306', '+7.1']
# ['POLAND', '531,889', '486,352', '+9.4']
# ['PORTUGAL', '228,290', '222,129', '+2.8']
# ...

# %%
eurosales2018 = pd.DataFrame(columns = ['Country'] + eurosales2018_data[0])

# %%
eurosales2018
# Out:
# Empty DataFrame
# Columns: [Country, FY 2018, FY2017, % Change]
# Index: []

# %%
eurosales2018_data[1:-1]
# Out:
# [['AUSTRIA', '341,068', '353,320', '-3.5'],
#  ['BELGIUM', '549,632', '546,558', '+0.6'],
#  ['BULGARIA', '34,332', '31,244', '+9.9'],
#  ['CROATIA', '59,856', '50,412', '+18.7'],
#  ['CYPRUS', '12,956', '13,080', '-0.9'],
#  ['CZECH REPUBLIC', '261,437', '271,595', '-3.7'],
#  ['DENMARK', '218,565', '221,838', '-1.5'],
#  ['ESTONIA', '25,387', '24,494', '+3.6'],
#  ['FINLAND', '120,499', '118,587', '+1.6'],
#  ['FRANCE', '2,173,481', '2,110,748', '+3.0'],
#  ['GERMANY', '3,435,778', '3,441,262', '-0.2'],
#  ['GREECE', '103,431', '88,083', '+17.4'],
#  ['HUNGARY', '136,594', '116,265', '+17.5'],
#  ['IRELAND', '125,557', '131,332', '-4.4'],
#  ['ITALY', '1,910,025', '1,971,345', '-3.1'],
#  ['LATVIA', '16,879', '16,692', '+1.1'],
#  ['LITHUANIA2', '32,447', '25,867', '+25.4'],
#  ['LUXEMBOURG', '52,811', '52,775', '+0.1'],
#  ['NETHERLANDS', '443,812', '414,306', '+7.1'],
#  ['POLAND', '531,889', '486,352', '+9.4'],
#  ['PORTUGAL', '228,290', '222,129', '+2.8'],
# ...

# %%
for i, row in enumerate(eurosales2018_data[1:-1]):
    for j, col in enumerate(eurosales2018.columns):
        eurosales2018.loc[i, col] = row[j]

# %%
eurosales2018
# Out:
#             Country     FY 2018      FY2017 % Change
# 0           AUSTRIA     341,068     353,320     -3.5
# 1           BELGIUM     549,632     546,558     +0.6
# 2          BULGARIA      34,332      31,244     +9.9
# 3           CROATIA      59,856      50,412    +18.7
# 4            CYPRUS      12,956      13,080     -0.9
# 5    CZECH REPUBLIC     261,437     271,595     -3.7
# 6           DENMARK     218,565     221,838     -1.5
# 7           ESTONIA      25,387      24,494     +3.6
# 8           FINLAND     120,499     118,587     +1.6
# 9            FRANCE   2,173,481   2,110,748     +3.0
# 10          GERMANY   3,435,778   3,441,262     -0.2
# 11           GREECE     103,431      88,083    +17.4
# 12          HUNGARY     136,594     116,265    +17.5
# 13          IRELAND     125,557     131,332     -4.4
# 14            ITALY   1,910,025   1,971,345     -3.1
# 15           LATVIA      16,879      16,692     +1.1
# 16       LITHUANIA2      32,447      25,867    +25.4
# ...

# %%
eurosales2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 4 columns):
# Country     33 non-null object
# FY 2018     33 non-null object
# FY2017      33 non-null object
# % Change    33 non-null object
# dtypes: object(4)
# memory usage: 2.5+ KB

# %%
eurosales2018['Country'].unique()
# Out:
# array(['AUSTRIA', 'BELGIUM', 'BULGARIA', 'CROATIA', 'CYPRUS',
#        'CZECH REPUBLIC', 'DENMARK', 'ESTONIA', 'FINLAND', 'FRANCE',
#        'GERMANY', 'GREECE', 'HUNGARY', 'IRELAND', 'ITALY', 'LATVIA',
#        'LITHUANIA2', 'LUXEMBOURG', 'NETHERLANDS', 'POLAND', 'PORTUGAL',
#        'ROMANIA', 'SLOVAKIA', 'SLOVENIA', 'SPAIN', 'SWEDEN',
#        'UNITED KINGDOM', 'EUROPEAN UNION*', 'ICELAND', 'NORWAY',
#        'SWITZERLAND', 'EFTA', 'EU* + EFTA'], dtype=object)

# %%
eurosales2018.columns
# Out:
# Index(['Country', 'FY 2018', 'FY2017', '% Change'], dtype='object')

# %%
eurosales2018 = eurosales2018.drop('% Change', axis = 1)

# %%
eurosales2018 = eurosales2018.applymap(lambda s: s.replace(',',''))

# %%
eurosales2018 = eurosales2018.applymap(lambda s: s.replace('*',''))

# %%
eurosales2018 = eurosales2018.applymap(lambda s: s.replace('LITHUANIA2','LITHUANIA'))

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017  ECV share 2017 [%]  Sales 2016  ECV Sales 2016  \
# 0       EU + EFTA    15631687                1.84    15131778          207068
# 1         AUSTRIA      353320                2.02      329604            5068
# 2         BELGIUM      546558                2.62      539519            8984
# 3        BULGARIA       31244                0.34       26370              13
# 4  CZECH REPUBLIC      271595                0.11      259693             200
#
#    ECV share 2016 [%]  ECV Sales 2018  ECV Sales 2017
# 0                1.37          384052          289072
# 1                1.54            8652            7154
# 2                1.67           13353           14459
# 3                0.05             220             106
# 4                0.08             981             387

# %%
ecv_europe = ecv_europe.merge(eurosales2018, how = 'inner', on = 'Country')

# %%
ecv_europe.head()
# Out:
#           Country  Sales 2017  ECV share 2017 [%]  Sales 2016  ECV Sales 2016  \
# 0       EU + EFTA    15631687                1.84    15131778          207068
# 1         AUSTRIA      353320                2.02      329604            5068
# 2         BELGIUM      546558                2.62      539519            8984
# 3        BULGARIA       31244                0.34       26370              13
# 4  CZECH REPUBLIC      271595                0.11      259693             200
#
#    ECV share 2016 [%]  ECV Sales 2018  ECV Sales 2017   FY 2018    FY2017
# 0                1.37          384052          289072  15624486  15630555
# 1                1.54            8652            7154    341068    353320
# 2                1.67           13353           14459    549632    546558
# 3                0.05             220             106     34332     31244
# 4                0.08             981             387    261437    271595

# %%
ecv_europe.drop('Sales 2017', axis = 1, inplace = True)

# %%
ecv_europe = ecv_europe.rename(columns = {'FY 2018':'Sales 2018', 'FY2017':'Sales 2017'})

# %%
ecv_europe.head()
# Out:
#           Country  ECV share 2017 [%]  Sales 2016  ECV Sales 2016  \
# 0       EU + EFTA                1.84    15131778          207068
# 1         AUSTRIA                2.02      329604            5068
# 2         BELGIUM                2.62      539519            8984
# 3        BULGARIA                0.34       26370              13
# 4  CZECH REPUBLIC                0.11      259693             200
#
#    ECV share 2016 [%]  ECV Sales 2018  ECV Sales 2017 Sales 2018 Sales 2017
# 0                1.37          384052          289072   15624486   15630555
# 1                1.54            8652            7154     341068     353320
# 2                1.67           13353           14459     549632     546558
# 3                0.05             220             106      34332      31244
# 4                0.08             981             387     261437     271595

# %%
ecv_europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 0 to 27
# Data columns (total 9 columns):
# Country               28 non-null object
# ECV share 2017 [%]    28 non-null float64
# Sales 2016            28 non-null int32
# ECV Sales 2016        28 non-null int32
# ECV share 2016 [%]    28 non-null float64
# ECV Sales 2018        28 non-null int32
# ECV Sales 2017        28 non-null int32
# Sales 2018            28 non-null object
# Sales 2017            28 non-null object
# dtypes: float64(2), int32(4), object(3)
# memory usage: 1.8+ KB

# %%
for year in [2017, 2018]:
    ecv_europe['Sales {}'.format(year)] = ecv_europe['Sales {}'.format(year)].astype(int)

# %%
for year in [2017, 2018]:
    ecv_europe['ECV share {} [%]'.format(year)] = ecv_europe['ECV Sales {}'.format(year)]/ecv_europe['Sales {}'.format(year)]*100

# %%
for year in [2017, 2018]:
    ecv_europe['ECV share {} [%]'.format(year)] = ecv_europe['ECV share {} [%]'.format(year)].round(2)

# %%
ecv_europe
# Out:
#            Country  ECV share 2017 [%]  Sales 2016  ECV Sales 2016  \
# 0        EU + EFTA                1.85    15131778          207068
# 1          AUSTRIA                2.02      329604            5068
# 2          BELGIUM                2.65      539519            8984
# 3         BULGARIA                0.34       26370              13
# 4   CZECH REPUBLIC                0.14      259693             200
# 5          DENMARK                0.60      222917            1920
# 6          ESTONIA                0.19       22429              35
# 7          FINLAND                2.58      119000            1430
# 8           FRANCE                1.75     2015177           29194
# 9          GERMANY                1.59     3351607           25214
# 10          GREECE                0.22       78873              43
# 11         HUNGARY                1.03       96552             343
# 12         IRELAND                0.72      146649             690
# ...
